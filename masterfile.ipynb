# %% [markdown]
# <a href="https://colab.research.google.com/github/ryueuitae-blip/first-project/blob/master/masterfile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(134)

print("우리 스터디 파이팅!")
# Out:
# 134
