# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 5.3 MB 10.8 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

arr= np.array([1,2,3,4])
arr10 = arr * 10

print(arr10)
# Out:
# [10 20 30 40]

# %%
price = [
    [100,80,70,90],
    [120,110,100,110]
]
print(price[0])
# Out:
# [100, 80, 70, 90]

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 10.8 MB 10.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 510 kB 35.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 348 kB 115.9 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
from pandas import Series
arr = [0,1,2,3]
s = Series(arr)
print(s)
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
data = [100,200,300]
s = Series(data)
print(s)
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
datadata = [100,200,300]
index = ["월","화","수"]
s = Series(data,index)
print(s)
# Out:
# 월    100
# 화    200
# 수    300
# dtype: int64

# %%
datadata = [100,200,300]
index = ["월","화","수"]
s = Series(data,index)
print(s.index)
print(s.values)
# Out:
# Index(['월', '화', '수'], dtype='object')
# [100 200 300]

# %%
s.array
# Out:
# <NumpyExtensionArray>
# [100, 200, 300]
# Length: 3, dtype: int64

# %%
data = [500,800,200]
index = ("메로나","누가바","빠삐코")
s = pd.Series(data,index)
print(s.index)
print(s.values)
# Out:
# Index(['메로나', '누가바', '빠삐코'], dtype='object')
# [500 800 200]
